# %%
# !pip install --upgrade opencv-python==4.9.0.80
# Out:
# Collecting opencv-python==4.9.0.80
#   Downloading opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python==4.9.0.80) (1.26.4)
# Downloading opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 11.8 MB/s eta 0:00:00
# Installing collected packages: opencv-python
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.10.0.84
#     Uninstalling opencv-python-4.10.0.84:
#       Successfully uninstalled opencv-python-4.10.0.84
# Successfully installed opencv-python-4.9.0.80

# %%
# !pip uninstall tensorflow -y
# Out:
# Found existing installation: tensorflow 2.17.0
# Uninstalling tensorflow-2.17.0:
#   Successfully uninstalled tensorflow-2.17.0

# %%
# !pip install tensorflow==2.15.0
# Out:
# Collecting tensorflow==2.15.0
#   Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (18.1.1)
# Collecting ml-dtypes~=0.2.0 (from tensorflow==2.15.0)
#   Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (4.12.2)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow==2.15.0)
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.64.1)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow==2.15.0)
#   Downloading tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow==2.15.0)
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow==2.15.0)
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.15.0) (0.44.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.0.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.2.2)
# Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 3.1 MB/s eta 0:00:00
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 73.9 MB/s eta 0:00:00
# Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 57.9 MB/s eta 0:00:00
# Downloading tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 87.1 MB/s eta 0:00:00
# Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 28.4 MB/s eta 0:00:00
# Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.1 MB/s eta 0:00:00
# Installing collected packages: wrapt, tensorflow-estimator, ml-dtypes, keras, tensorboard, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.16.0
#     Uninstalling wrapt-1.16.0:
#       Successfully uninstalled wrapt-1.16.0
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
#   Attempting uninstall: keras
#     Found existing installation: keras 3.4.1
#     Uninstalling keras-3.4.1:
#       Successfully uninstalled keras-3.4.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.0
#     Uninstalling tensorboard-2.17.0:
#       Successfully uninstalled tensorboard-2.17.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorstore 0.1.65 requires ml-dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.
# tf-keras 2.17.0 requires tensorflow<2.18,>=2.17, but you have tensorflow 2.15.0 which is incompatible.
# Successfully installed keras-2.15.0 ml-dtypes-0.2.0 tensorboard-2.15.2 tensorflow-2.15.0 tensorflow-estimator-2.15.0 wrapt-1.14.1

# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.15.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## Imports
import os
import sys
import random

import numpy as np
import cv2
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras



## Seeding
seed = 2019
random.seed = seed
np.random.seed = seed
tf.seed = seed

# %%
image_size = 256
train_path = "/content/drive/MyDrive/"
epochs = 100
batch_size = 8

# %%
import os
import cv2
import numpy as np
from tensorflow import keras

class DataGen(keras.utils.Sequence):
    def __init__(self, ids, path, batch_size, image_size=128):
        self.batch_size = batch_size
        self.image_size = image_size
        self.ids = ids
        self.mask_ids = ids
        self.path = path
        self.on_epoch_end()

    def __load__(self, id_name, mask_id_name):
        image_path = os.path.join(self.path, "IMAGES_OK", id_name) + ".jpg"
        mask_path = os.path.join(self.path, "MASKS_PLS/", mask_id_name) + ".jpg"

        image = cv2.imread(image_path, 1)
        image = cv2.resize(image, (self.image_size, self.image_size))

        mask = cv2.imread(mask_path, 1)
        mask = cv2.resize(mask, (self.image_size, self.image_size))
        mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
        mask = np.expand_dims(mask, axis=-1)

        image = image / 255.0
        mask = mask / 255.0

        return image, mask

    def __getitem__(self, index):
        if (index + 1) * self.batch_size > len(self.ids):
            self.batch_size = len(self.ids) - index * self.batch_size

        files_batch = self.ids[index * self.batch_size: (index + 1) * self.batch_size]
        mask_files_batch = self.mask_ids[index * self.batch_size: (index + 1) * self.batch_size]

        image = []
        mask = []

        for id_name, mask_id_name in zip(files_batch, mask_files_batch):
            _img, _mask = self.__load__(id_name, mask_id_name)
            image.append(_img)
            mask.append(_mask)

        image = np.array(image)
        mask = np.array(mask)

        return image, mask

    def on_epoch_end(self):
        pass

    def __len__(self):
        return int(np.ceil(len(self.ids) / float(self.batch_size)))


class TestGen(keras.utils.Sequence):
    def __init__(self, ids, path, batch_size, image_size=128):
        self.batch_size = 8
        self.image_size = image_size
        self.ids = ids
        self.path = path

    def __load__(self, id_name):
        image_path = os.path.join(self.path, "IMAGES_OK/", id_name) + ".jpg"
        mask_path = os.path.join(self.path, "MASKS_PLS/", id_name) + ".jpg"

        image = cv2.imread(image_path, 1)
        image = cv2.resize(image, (self.image_size, self.image_size))
        image = image / 255.0

        mask = cv2.imread(mask_path, 1)
        mask = cv2.resize(mask, (self.image_size, self.image_size))
        mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
        mask = np.expand_dims(mask, axis=-1)
        mask = mask / 255.0

        return image, mask

    def __getitem__(self, index):
        if (index + 1) * self.batch_size > len(self.ids):
            self.batch_size = len(self.ids) - index * self.batch_size

        files_batch = self.ids[index * self.batch_size: (index + 1) * self.batch_size]

        image = []
        mask = []

        for id_name in files_batch:
            _img, _mask = self.__load__(id_name)
            image.append(_img)
            mask.append(_mask)

        image = np.array(image)
        mask = np.array(mask)

        return image, mask

    def __len__(self):
        return int(np.ceil(len(self.ids) / float(self.batch_size)))

# %%
# 30 original images, each with 7 samples (total of 210 images)

train_ids = ['IDRiD_{:03d}_{:d}'.format(i, j) for i in range(1, 25) for j in range(7)]  # 80% for training (168 images)
test_ids = ['IDRiD_{:03d}_{:d}'.format(i, j) for i in range(25, 28) for j in range(7)]  # 10% for testing (21 images)
valid_ids = ['IDRiD_{:03d}_{:d}'.format(i, j) for i in range(28, 31) for j in range(7)]  # 10% for validation (21 images)

# %%
for i in range(len(valid_ids)):
    print(valid_ids[i], train_ids[i], test_ids[i])
# Out:
# IDRiD_028_0 IDRiD_001_0 IDRiD_025_0
# IDRiD_028_1 IDRiD_001_1 IDRiD_025_1
# IDRiD_028_2 IDRiD_001_2 IDRiD_025_2
# IDRiD_028_3 IDRiD_001_3 IDRiD_025_3
# IDRiD_028_4 IDRiD_001_4 IDRiD_025_4
# IDRiD_028_5 IDRiD_001_5 IDRiD_025_5
# IDRiD_028_6 IDRiD_001_6 IDRiD_025_6
# IDRiD_029_0 IDRiD_002_0 IDRiD_026_0
# IDRiD_029_1 IDRiD_002_1 IDRiD_026_1
# IDRiD_029_2 IDRiD_002_2 IDRiD_026_2
# IDRiD_029_3 IDRiD_002_3 IDRiD_026_3
# IDRiD_029_4 IDRiD_002_4 IDRiD_026_4
# IDRiD_029_5 IDRiD_002_5 IDRiD_026_5
# IDRiD_029_6 IDRiD_002_6 IDRiD_026_6
# IDRiD_030_0 IDRiD_003_0 IDRiD_027_0
# IDRiD_030_1 IDRiD_003_1 IDRiD_027_1
# IDRiD_030_2 IDRiD_003_2 IDRiD_027_2
# IDRiD_030_3 IDRiD_003_3 IDRiD_027_3
# IDRiD_030_4 IDRiD_003_4 IDRiD_027_4
# IDRiD_030_5 IDRiD_003_5 IDRiD_027_5
# IDRiD_030_6 IDRiD_003_6 IDRiD_027_6

# %%
gen = DataGen(train_ids, train_path, batch_size, image_size=image_size)
x, y = gen.__getitem__(0)
print(x.shape, y.shape)
# Out:
# (8, 256, 256, 3) (8, 256, 256, 1)

# %%
test_gen = TestGen(test_ids, train_path, batch_size, image_size=image_size)
X,Y = test_gen.__getitem__(0)
print(X.shape, Y.shape)
# Out:
# (8, 256, 256, 3) (8, 256, 256, 1)

# %%
r = random.randint(0, len(x)-1)

fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
ax = fig.add_subplot(1, 2, 1)
ax.imshow(x[r])
ax = fig.add_subplot(1, 2, 2)
ax.imshow(np.reshape(y[r], (image_size, image_size)), cmap="gray")

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPooling2D, Conv2DTranspose
from tensorflow.keras.layers import Concatenate, Input
from tensorflow.keras.models import Model

def conv_block(x, num_filters, kernel_size, padding="same", act=True):
    x = tf.keras.layers.Conv2D(num_filters, kernel_size, padding=padding, use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    if act:
        x = tf.keras.layers.Activation("relu")(x)
    return x

def multires_block(x, num_filters, alpha=1.67):
    W = num_filters * alpha

    x0 = x
    x1 = conv_block(x0, int(W*0.167), 3)
    x2 = conv_block(x1, int(W*0.333), 3)
    x3 = conv_block(x2, int(W*0.5), 3)
    xc = tf.keras.layers.Concatenate()([x1, x2, x3])
    xc = tf.keras.layers.BatchNormalization()(xc)

    nf = int(W*0.167) + int(W*0.333) + int(W*0.5)
    sc = conv_block(x0, nf, 1, act=False)

    x = tf.keras.layers.Activation("relu")(xc + sc)
    x = tf.keras.layers.BatchNormalization()(x)
    return x

# %%
def res_path(x, num_filters, length):
    for i in range(length):
        x0 = x
        x1 = conv_block(x0, num_filters, 3, act=False)
        sc = conv_block(x0, num_filters, 1, act=False)
        x = tf.keras.layers.Activation("relu")(x1 + sc)
        x = tf.keras.layers.BatchNormalization()(x)
    return x

def encoder_block(x, num_filters, length):
    x = multires_block(x, num_filters)
    s = res_path(x, num_filters, length)
    p = tf.keras.layers.MaxPooling2D((2, 2))(x)
    return s, p

def decoder_block(x, skip, num_filters):
    x = tf.keras.layers.Conv2DTranspose(num_filters, 2, strides=2, padding="same")(x)
    x = tf.keras.layers.Concatenate()([x, skip])
    x = multires_block(x, num_filters)
    return x

def build_multiresunet(shape):
    """ Input """
    inputs = tf.keras.layers.Input(shape)

    """ Encoder """
    p0 = inputs
    s1, p1 = encoder_block(p0, 32, 4)
    s2, p2 = encoder_block(p1, 64, 3)
    s3, p3 = encoder_block(p2, 128, 2)
    s4, p4 = encoder_block(p3, 256, 1)

    """ Bridge """
    b1 = multires_block(p4, 512)

    """ Decoder """
    d1 = decoder_block(b1, s4, 256)
    d2 = decoder_block(d1, s3, 128)
    d3 = decoder_block(d2, s2, 64)
    d4 = decoder_block(d3, s1, 32)

    """ Output """
    outputs = tf.keras.layers.Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    """ Model """
    model = tf.keras.models.Model(inputs, outputs, name="MultiResUNET")

    return model

# %%
smooth = 1.
import tensorflow as tf
from keras import backend as K
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
shape = (256, 256, 3)
adam = keras.optimizers.Adam()
model = build_multiresunet(shape)
model.compile(optimizer=adam, loss=dice_coef_loss, metrics=[dice_coef])
model.summary()
# Out:
# Model: "MultiResUNET"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 256, 256, 8)          216       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 256, 256, 8)          32        ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 256, 256, 8)          0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 17)         1224      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 256, 256, 17)         68        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 256, 256, 17)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 256, 256, 26)         3978      ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 256, 256, 26)         104       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 256, 256, 26)         0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  concatenate (Concatenate)   (None, 256, 256, 51)         0         ['activation[0][0]',
#                                                                      'activation_1[0][0]',
#                                                                      'activation_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 256, 256, 51)         153       ['input_1[0][0]']
#
#  batch_normalization_3 (Bat  (None, 256, 256, 51)         204       ['concatenate[0][0]']
#  chNormalization)
#
#  batch_normalization_4 (Bat  (None, 256, 256, 51)         204       ['conv2d_3[0][0]']
#  chNormalization)
#
#  tf.__operators__.add (TFOp  (None, 256, 256, 51)         0         ['batch_normalization_3[0][0]'
#  Lambda)                                                            , 'batch_normalization_4[0][0]
#                                                                     ']
#
#  activation_3 (Activation)   (None, 256, 256, 51)         0         ['tf.__operators__.add[0][0]']
#
#  batch_normalization_5 (Bat  (None, 256, 256, 51)         204       ['activation_3[0][0]']
#  chNormalization)
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 51)         0         ['batch_normalization_5[0][0]'
#  D)                                                                 ]
#
#  conv2d_12 (Conv2D)          (None, 128, 128, 17)         7803      ['max_pooling2d[0][0]']
#
#  batch_normalization_18 (Ba  (None, 128, 128, 17)         68        ['conv2d_12[0][0]']
#  tchNormalization)
#
#  activation_8 (Activation)   (None, 128, 128, 17)         0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 128, 128, 35)         5355      ['activation_8[0][0]']
#
#  batch_normalization_19 (Ba  (None, 128, 128, 35)         140       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  activation_9 (Activation)   (None, 128, 128, 35)         0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_14 (Conv2D)          (None, 128, 128, 53)         16695     ['activation_9[0][0]']
#
#  batch_normalization_20 (Ba  (None, 128, 128, 53)         212       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 128, 128, 53)         0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  concatenate_1 (Concatenate  (None, 128, 128, 105)        0         ['activation_8[0][0]',
#  )                                                                   'activation_9[0][0]',
#                                                                      'activation_10[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 128, 128, 105)        5355      ['max_pooling2d[0][0]']
#
#  batch_normalization_21 (Ba  (None, 128, 128, 105)        420       ['concatenate_1[0][0]']
#  tchNormalization)
#
#  batch_normalization_22 (Ba  (None, 128, 128, 105)        420       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  tf.__operators__.add_5 (TF  (None, 128, 128, 105)        0         ['batch_normalization_21[0][0]
#  OpLambda)                                                          ',
#                                                                      'batch_normalization_22[0][0]
#                                                                     ']
#
#  activation_11 (Activation)  (None, 128, 128, 105)        0         ['tf.__operators__.add_5[0][0]
#                                                                     ']
#
#  batch_normalization_23 (Ba  (None, 128, 128, 105)        420       ['activation_11[0][0]']
#  tchNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 105)          0         ['batch_normalization_23[0][0]
#  g2D)                                                               ']
#
#  conv2d_22 (Conv2D)          (None, 64, 64, 35)           33075     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_33 (Ba  (None, 64, 64, 35)           140       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 64, 64, 35)           0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv2d_23 (Conv2D)          (None, 64, 64, 71)           22365     ['activation_15[0][0]']
#
#  batch_normalization_34 (Ba  (None, 64, 64, 71)           284       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 64, 64, 71)           0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 64, 64, 106)          67734     ['activation_16[0][0]']
#
#  batch_normalization_35 (Ba  (None, 64, 64, 106)          424       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 64, 64, 106)          0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  concatenate_2 (Concatenate  (None, 64, 64, 212)          0         ['activation_15[0][0]',
#  )                                                                   'activation_16[0][0]',
#                                                                      'activation_17[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 64, 64, 212)          22260     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_36 (Ba  (None, 64, 64, 212)          848       ['concatenate_2[0][0]']
#  tchNormalization)
#
#  batch_normalization_37 (Ba  (None, 64, 64, 212)          848       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  tf.__operators__.add_9 (TF  (None, 64, 64, 212)          0         ['batch_normalization_36[0][0]
#  OpLambda)                                                          ',
#                                                                      'batch_normalization_37[0][0]
#                                                                     ']
#
#  activation_18 (Activation)  (None, 64, 64, 212)          0         ['tf.__operators__.add_9[0][0]
#                                                                     ']
#
#  batch_normalization_38 (Ba  (None, 64, 64, 212)          848       ['activation_18[0][0]']
#  tchNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 32, 212)          0         ['batch_normalization_38[0][0]
#  g2D)                                                               ']
#
#  conv2d_30 (Conv2D)          (None, 32, 32, 71)           135468    ['max_pooling2d_2[0][0]']
#
#  batch_normalization_45 (Ba  (None, 32, 32, 71)           284       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 32, 32, 71)           0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 32, 32, 142)          90738     ['activation_21[0][0]']
#
#  batch_normalization_46 (Ba  (None, 32, 32, 142)          568       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 32, 32, 142)          0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 32, 32, 213)          272214    ['activation_22[0][0]']
#
#  batch_normalization_47 (Ba  (None, 32, 32, 213)          852       ['conv2d_32[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 32, 32, 213)          0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  concatenate_3 (Concatenate  (None, 32, 32, 426)          0         ['activation_21[0][0]',
#  )                                                                   'activation_22[0][0]',
#                                                                      'activation_23[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 32, 32, 426)          90312     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_48 (Ba  (None, 32, 32, 426)          1704      ['concatenate_3[0][0]']
#  tchNormalization)
#
#  batch_normalization_49 (Ba  (None, 32, 32, 426)          1704      ['conv2d_33[0][0]']
#  tchNormalization)
#
#  tf.__operators__.add_12 (T  (None, 32, 32, 426)          0         ['batch_normalization_48[0][0]
#  FOpLambda)                                                         ',
#                                                                      'batch_normalization_49[0][0]
#                                                                     ']
#
#  activation_24 (Activation)  (None, 32, 32, 426)          0         ['tf.__operators__.add_12[0][0
#                                                                     ]']
#
#  batch_normalization_50 (Ba  (None, 32, 32, 426)          1704      ['activation_24[0][0]']
#  tchNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 426)          0         ['batch_normalization_50[0][0]
#  g2D)                                                               ']
#
#  conv2d_36 (Conv2D)          (None, 16, 16, 142)          544428    ['max_pooling2d_3[0][0]']
#
#  batch_normalization_54 (Ba  (None, 16, 16, 142)          568       ['conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 16, 16, 142)          0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 16, 16, 284)          362952    ['activation_26[0][0]']
#
#  batch_normalization_55 (Ba  (None, 16, 16, 284)          1136      ['conv2d_37[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 16, 16, 284)          0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  conv2d_38 (Conv2D)          (None, 16, 16, 427)          1091412   ['activation_27[0][0]']
#
#  batch_normalization_56 (Ba  (None, 16, 16, 427)          1708      ['conv2d_38[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 16, 16, 427)          0         ['batch_normalization_56[0][0]
#                                                                     ']
#
#  concatenate_4 (Concatenate  (None, 16, 16, 853)          0         ['activation_26[0][0]',
#  )                                                                   'activation_27[0][0]',
#                                                                      'activation_28[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 16, 16, 853)          363378    ['max_pooling2d_3[0][0]']
#
#  batch_normalization_57 (Ba  (None, 16, 16, 853)          3412      ['concatenate_4[0][0]']
#  tchNormalization)
#
#  batch_normalization_58 (Ba  (None, 16, 16, 853)          3412      ['conv2d_39[0][0]']
#  tchNormalization)
#
#  conv2d_34 (Conv2D)          (None, 32, 32, 256)          981504    ['batch_normalization_50[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 32, 32, 256)          109056    ['batch_normalization_50[0][0]
#                                                                     ']
#
#  tf.__operators__.add_14 (T  (None, 16, 16, 853)          0         ['batch_normalization_57[0][0]
#  FOpLambda)                                                         ',
#                                                                      'batch_normalization_58[0][0]
#                                                                     ']
#
#  batch_normalization_51 (Ba  (None, 32, 32, 256)          1024      ['conv2d_34[0][0]']
#  tchNormalization)
#
#  batch_normalization_52 (Ba  (None, 32, 32, 256)          1024      ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 16, 16, 853)          0         ['tf.__operators__.add_14[0][0
#                                                                     ]']
#
#  tf.__operators__.add_13 (T  (None, 32, 32, 256)          0         ['batch_normalization_51[0][0]
#  FOpLambda)                                                         ',
#                                                                      'batch_normalization_52[0][0]
#                                                                     ']
#
#  batch_normalization_59 (Ba  (None, 16, 16, 853)          3412      ['activation_29[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 32, 32, 256)          0         ['tf.__operators__.add_13[0][0
#                                                                     ]']
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 256)          873728    ['batch_normalization_59[0][0]
#  anspose)                                                           ']
#
#  batch_normalization_53 (Ba  (None, 32, 32, 256)          1024      ['activation_25[0][0]']
#  tchNormalization)
#
#  concatenate_5 (Concatenate  (None, 32, 32, 512)          0         ['conv2d_transpose[0][0]',
#  )                                                                   'batch_normalization_53[0][0]
#                                                                     ']
#
#  conv2d_40 (Conv2D)          (None, 32, 32, 71)           327168    ['concatenate_5[0][0]']
#
#  batch_normalization_60 (Ba  (None, 32, 32, 71)           284       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 32, 32, 71)           0         ['batch_normalization_60[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 32, 32, 142)          90738     ['activation_30[0][0]']
#
#  batch_normalization_61 (Ba  (None, 32, 32, 142)          568       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 32, 32, 142)          0         ['batch_normalization_61[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 64, 64, 128)          244224    ['batch_normalization_38[0][0]
#                                                                     ']
#
#  conv2d_27 (Conv2D)          (None, 64, 64, 128)          27136     ['batch_normalization_38[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 32, 32, 213)          272214    ['activation_31[0][0]']
#
#  batch_normalization_39 (Ba  (None, 64, 64, 128)          512       ['conv2d_26[0][0]']
#  tchNormalization)
#
#  batch_normalization_40 (Ba  (None, 64, 64, 128)          512       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  batch_normalization_62 (Ba  (None, 32, 32, 213)          852       ['conv2d_42[0][0]']
#  tchNormalization)
#
#  tf.__operators__.add_10 (T  (None, 64, 64, 128)          0         ['batch_normalization_39[0][0]
#  FOpLambda)                                                         ',
#                                                                      'batch_normalization_40[0][0]
#                                                                     ']
#
#  activation_32 (Activation)  (None, 32, 32, 213)          0         ['batch_normalization_62[0][0]
#                                                                     ']
#
#  activation_19 (Activation)  (None, 64, 64, 128)          0         ['tf.__operators__.add_10[0][0
#                                                                     ]']
#
#  concatenate_6 (Concatenate  (None, 32, 32, 426)          0         ['activation_30[0][0]',
#  )                                                                   'activation_31[0][0]',
#                                                                      'activation_32[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 32, 32, 426)          218112    ['concatenate_5[0][0]']
#
#  batch_normalization_41 (Ba  (None, 64, 64, 128)          512       ['activation_19[0][0]']
#  tchNormalization)
#
#  batch_normalization_63 (Ba  (None, 32, 32, 426)          1704      ['concatenate_6[0][0]']
#  tchNormalization)
#
#  batch_normalization_64 (Ba  (None, 32, 32, 426)          1704      ['conv2d_43[0][0]']
#  tchNormalization)
#
#  conv2d_28 (Conv2D)          (None, 64, 64, 128)          147456    ['batch_normalization_41[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 64, 64, 128)          16384     ['batch_normalization_41[0][0]
#                                                                     ']
#
#  tf.__operators__.add_15 (T  (None, 32, 32, 426)          0         ['batch_normalization_63[0][0]
#  FOpLambda)                                                         ',
#                                                                      'batch_normalization_64[0][0]
#                                                                     ']
#
#  batch_normalization_42 (Ba  (None, 64, 64, 128)          512       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  batch_normalization_43 (Ba  (None, 64, 64, 128)          512       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 32, 32, 426)          0         ['tf.__operators__.add_15[0][0
#                                                                     ]']
#
#  tf.__operators__.add_11 (T  (None, 64, 64, 128)          0         ['batch_normalization_42[0][0]
#  FOpLambda)                                                         ',
#                                                                      'batch_normalization_43[0][0]
#                                                                     ']
#
#  batch_normalization_65 (Ba  (None, 32, 32, 426)          1704      ['activation_33[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 64, 64, 128)          0         ['tf.__operators__.add_11[0][0
#                                                                     ]']
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 64, 128)          218240    ['batch_normalization_65[0][0]
#  Transpose)                                                         ']
#
#  batch_normalization_44 (Ba  (None, 64, 64, 128)          512       ['activation_20[0][0]']
#  tchNormalization)
#
#  concatenate_7 (Concatenate  (None, 64, 64, 256)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_44 (Conv2D)          (None, 64, 64, 35)           80640     ['concatenate_7[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 128, 128, 64)         60480     ['batch_normalization_23[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 128, 128, 64)         6720      ['batch_normalization_23[0][0]
#                                                                     ']
#
#  batch_normalization_66 (Ba  (None, 64, 64, 35)           140       ['conv2d_44[0][0]']
#  tchNormalization)
#
#  batch_normalization_24 (Ba  (None, 128, 128, 64)         256       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  batch_normalization_25 (Ba  (None, 128, 128, 64)         256       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 64, 64, 35)           0         ['batch_normalization_66[0][0]
#                                                                     ']
#
#  tf.__operators__.add_6 (TF  (None, 128, 128, 64)         0         ['batch_normalization_24[0][0]
#  OpLambda)                                                          ',
#                                                                      'batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 64, 64, 71)           22365     ['activation_34[0][0]']
#
#  activation_12 (Activation)  (None, 128, 128, 64)         0         ['tf.__operators__.add_6[0][0]
#                                                                     ']
#
#  batch_normalization_67 (Ba  (None, 64, 64, 71)           284       ['conv2d_45[0][0]']
#  tchNormalization)
#
#  batch_normalization_26 (Ba  (None, 128, 128, 64)         256       ['activation_12[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 64, 64, 71)           0         ['batch_normalization_67[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 128, 128, 64)         36864     ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 128, 128, 64)         4096      ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_46 (Conv2D)          (None, 64, 64, 106)          67734     ['activation_35[0][0]']
#
#  batch_normalization_27 (Ba  (None, 128, 128, 64)         256       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  batch_normalization_28 (Ba  (None, 128, 128, 64)         256       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  batch_normalization_68 (Ba  (None, 64, 64, 106)          424       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  tf.__operators__.add_7 (TF  (None, 128, 128, 64)         0         ['batch_normalization_27[0][0]
#  OpLambda)                                                          ',
#                                                                      'batch_normalization_28[0][0]
#                                                                     ']
#
#  activation_36 (Activation)  (None, 64, 64, 106)          0         ['batch_normalization_68[0][0]
#                                                                     ']
#
#  activation_13 (Activation)  (None, 128, 128, 64)         0         ['tf.__operators__.add_7[0][0]
#                                                                     ']
#
#  concatenate_8 (Concatenate  (None, 64, 64, 212)          0         ['activation_34[0][0]',
#  )                                                                   'activation_35[0][0]',
#                                                                      'activation_36[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 64, 64, 212)          54272     ['concatenate_7[0][0]']
#
#  batch_normalization_29 (Ba  (None, 128, 128, 64)         256       ['activation_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_69 (Ba  (None, 64, 64, 212)          848       ['concatenate_8[0][0]']
#  tchNormalization)
#
#  batch_normalization_70 (Ba  (None, 64, 64, 212)          848       ['conv2d_47[0][0]']
#  tchNormalization)
#
#  conv2d_20 (Conv2D)          (None, 128, 128, 64)         36864     ['batch_normalization_29[0][0]
#                                                                     ']
#
#  conv2d_21 (Conv2D)          (None, 128, 128, 64)         4096      ['batch_normalization_29[0][0]
#                                                                     ']
#
#  tf.__operators__.add_16 (T  (None, 64, 64, 212)          0         ['batch_normalization_69[0][0]
#  FOpLambda)                                                         ',
#                                                                      'batch_normalization_70[0][0]
#                                                                     ']
#
#  batch_normalization_30 (Ba  (None, 128, 128, 64)         256       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  batch_normalization_31 (Ba  (None, 128, 128, 64)         256       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  conv2d_4 (Conv2D)           (None, 256, 256, 32)         14688     ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 256, 256, 32)         1632      ['batch_normalization_5[0][0]'
#                                                                     ]
#
# ...
#  batch_normalization_10 (Ba  (None, 256, 256, 32)         128       ['conv2d_7[0][0]']
#  tchNormalization)
#
#  activation_38 (Activation)  (None, 128, 128, 17)         0         ['batch_normalization_72[0][0]
#                                                                     ']
#
#  tf.__operators__.add_2 (TF  (None, 256, 256, 32)         0         ['batch_normalization_9[0][0]'
#  OpLambda)                                                          , 'batch_normalization_10[0][0
#                                                                     ]']
#
#  conv2d_49 (Conv2D)          (None, 128, 128, 35)         5355      ['activation_38[0][0]']
#
#  activation_5 (Activation)   (None, 256, 256, 32)         0         ['tf.__operators__.add_2[0][0]
#                                                                     ']
#
#  batch_normalization_73 (Ba  (None, 128, 128, 35)         140       ['conv2d_49[0][0]']
#  tchNormalization)
#
#  batch_normalization_11 (Ba  (None, 256, 256, 32)         128       ['activation_5[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 128, 128, 35)         0         ['batch_normalization_73[0][0]
#                                                                     ']
#
#  conv2d_8 (Conv2D)           (None, 256, 256, 32)         9216      ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_9 (Conv2D)           (None, 256, 256, 32)         1024      ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_50 (Conv2D)          (None, 128, 128, 53)         16695     ['activation_39[0][0]']
#
#  batch_normalization_12 (Ba  (None, 256, 256, 32)         128       ['conv2d_8[0][0]']
#  tchNormalization)
#
#  batch_normalization_13 (Ba  (None, 256, 256, 32)         128       ['conv2d_9[0][0]']
#  tchNormalization)
#
#  batch_normalization_74 (Ba  (None, 128, 128, 53)         212       ['conv2d_50[0][0]']
#  tchNormalization)
#
#  tf.__operators__.add_3 (TF  (None, 256, 256, 32)         0         ['batch_normalization_12[0][0]
#  OpLambda)                                                          ',
#                                                                      'batch_normalization_13[0][0]
#                                                                     ']
#
#  activation_40 (Activation)  (None, 128, 128, 53)         0         ['batch_normalization_74[0][0]
#                                                                     ']
#
#  activation_6 (Activation)   (None, 256, 256, 32)         0         ['tf.__operators__.add_3[0][0]
#                                                                     ']
#
#  concatenate_10 (Concatenat  (None, 128, 128, 105)        0         ['activation_38[0][0]',
#  e)                                                                  'activation_39[0][0]',
#                                                                      'activation_40[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 128, 128, 105)        13440     ['concatenate_9[0][0]']
#
#  batch_normalization_14 (Ba  (None, 256, 256, 32)         128       ['activation_6[0][0]']
#  tchNormalization)
#
#  batch_normalization_75 (Ba  (None, 128, 128, 105)        420       ['concatenate_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_76 (Ba  (None, 128, 128, 105)        420       ['conv2d_51[0][0]']
#  tchNormalization)
#
#  conv2d_10 (Conv2D)          (None, 256, 256, 32)         9216      ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_11 (Conv2D)          (None, 256, 256, 32)         1024      ['batch_normalization_14[0][0]
#                                                                     ']
#
#  tf.__operators__.add_17 (T  (None, 128, 128, 105)        0         ['batch_normalization_75[0][0]
#  FOpLambda)                                                         ',
#                                                                      'batch_normalization_76[0][0]
#                                                                     ']
#
#  batch_normalization_15 (Ba  (None, 256, 256, 32)         128       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 256, 256, 32)         128       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_41 (Activation)  (None, 128, 128, 105)        0         ['tf.__operators__.add_17[0][0
#                                                                     ]']
#
#  tf.__operators__.add_4 (TF  (None, 256, 256, 32)         0         ['batch_normalization_15[0][0]
#  OpLambda)                                                          ',
#                                                                      'batch_normalization_16[0][0]
#                                                                     ']
#
#  batch_normalization_77 (Ba  (None, 128, 128, 105)        420       ['activation_41[0][0]']
#  tchNormalization)
#
#  activation_7 (Activation)   (None, 256, 256, 32)         0         ['tf.__operators__.add_4[0][0]
#                                                                     ']
#
#  conv2d_transpose_3 (Conv2D  (None, 256, 256, 32)         13472     ['batch_normalization_77[0][0]
#  Transpose)                                                         ']
#
#  batch_normalization_17 (Ba  (None, 256, 256, 32)         128       ['activation_7[0][0]']
#  tchNormalization)
#
#  concatenate_11 (Concatenat  (None, 256, 256, 64)         0         ['conv2d_transpose_3[0][0]',
#  e)                                                                  'batch_normalization_17[0][0]
#                                                                     ']
#
#  conv2d_52 (Conv2D)          (None, 256, 256, 8)          4608      ['concatenate_11[0][0]']
#
#  batch_normalization_78 (Ba  (None, 256, 256, 8)          32        ['conv2d_52[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 256, 256, 8)          0         ['batch_normalization_78[0][0]
#                                                                     ']
#
#  conv2d_53 (Conv2D)          (None, 256, 256, 17)         1224      ['activation_42[0][0]']
#
#  batch_normalization_79 (Ba  (None, 256, 256, 17)         68        ['conv2d_53[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 256, 256, 17)         0         ['batch_normalization_79[0][0]
#                                                                     ']
#
#  conv2d_54 (Conv2D)          (None, 256, 256, 26)         3978      ['activation_43[0][0]']
#
#  batch_normalization_80 (Ba  (None, 256, 256, 26)         104       ['conv2d_54[0][0]']
#  tchNormalization)
#
#  activation_44 (Activation)  (None, 256, 256, 26)         0         ['batch_normalization_80[0][0]
#                                                                     ']
#
#  concatenate_12 (Concatenat  (None, 256, 256, 51)         0         ['activation_42[0][0]',
#  e)                                                                  'activation_43[0][0]',
#                                                                      'activation_44[0][0]']
#
#  conv2d_55 (Conv2D)          (None, 256, 256, 51)         3264      ['concatenate_11[0][0]']
#
#  batch_normalization_81 (Ba  (None, 256, 256, 51)         204       ['concatenate_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_82 (Ba  (None, 256, 256, 51)         204       ['conv2d_55[0][0]']
#  tchNormalization)
#
#  tf.__operators__.add_18 (T  (None, 256, 256, 51)         0         ['batch_normalization_81[0][0]
#  FOpLambda)                                                         ',
#                                                                      'batch_normalization_82[0][0]
#                                                                     ']
#
#  activation_45 (Activation)  (None, 256, 256, 51)         0         ['tf.__operators__.add_18[0][0
#                                                                     ]']
#
#  batch_normalization_83 (Ba  (None, 256, 256, 51)         204       ['activation_45[0][0]']
#  tchNormalization)
#
#  conv2d_56 (Conv2D)          (None, 256, 256, 1)          52        ['batch_normalization_83[0][0]
#                                                                     ']
#
# ==================================================================================================
# Total params: 7269294 (27.73 MB)
# Trainable params: 7244774 (27.64 MB)
# Non-trainable params: 24520 (95.78 KB)
# __________________________________________________________________________________________________

# %%
train_gen = DataGen(train_ids, train_path, image_size=image_size, batch_size=batch_size)
valid_gen = DataGen(valid_ids, train_path, image_size=image_size, batch_size=batch_size)
test_gen = TestGen(test_ids, train_path, image_size=image_size, batch_size=8)
# Determine the number of steps per epoch
train_steps = len(train_ids) // batch_size
valid_steps = len(valid_ids) // batch_size
test_steps = len(test_ids) // batch_size

# If the length of the data is not evenly divisible by the batch size, add 1 additional step
if len(train_ids) % batch_size != 0:
    train_steps += 1
if len(valid_ids) % batch_size != 0:
    valid_steps += 1
if len(test_ids) % batch_size != 0:
    test_steps += 1

epochs = 100

history = model.fit(train_gen, validation_data=valid_gen, validation_steps=valid_steps,
                              epochs=epochs, steps_per_epoch=train_steps, verbose=1)

# Evaluate the model on the test data
test_results = model.evaluate(test_gen, steps=test_steps)
print("Test Loss:", test_results[0])
print("Test Accuracy:", test_results[1])
# Out:
# Epoch 1/100
# 21/21 [==============================] - 143s 7s/step - loss: 0.9600 - dice_coef: 0.0400 - val_loss: 0.9798 - val_dice_coef: 0.0198
# Epoch 2/100
# 21/21 [==============================] - 32s 2s/step - loss: 0.9349 - dice_coef: 0.0651 - val_loss: 0.9373 - val_dice_coef: 0.0627
# Epoch 3/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.9145 - dice_coef: 0.0855 - val_loss: 0.9897 - val_dice_coef: 0.0103
# Epoch 4/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.8801 - dice_coef: 0.1199 - val_loss: 0.9905 - val_dice_coef: 0.0095
# Epoch 5/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.8306 - dice_coef: 0.1694 - val_loss: 0.9921 - val_dice_coef: 0.0079
# Epoch 6/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.7681 - dice_coef: 0.2319 - val_loss: 0.9950 - val_dice_coef: 0.0050
# Epoch 7/100
# 21/21 [==============================] - 33s 2s/step - loss: 0.7268 - dice_coef: 0.2732 - val_loss: 0.9911 - val_dice_coef: 0.0089
# Epoch 8/100
# 21/21 [==============================] - 34s 2s/step - loss: 0.6642 - dice_coef: 0.3358 - val_loss: 0.9560 - val_dice_coef: 0.0440
# Epoch 9/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.6244 - dice_coef: 0.3756 - val_loss: 0.9881 - val_dice_coef: 0.0119
# Epoch 10/100
# 21/21 [==============================] - 30s 1s/step - loss: 0.6246 - dice_coef: 0.3754 - val_loss: 0.9914 - val_dice_coef: 0.0086
# Epoch 11/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.6013 - dice_coef: 0.3987 - val_loss: 0.9935 - val_dice_coef: 0.0065
# Epoch 12/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5907 - dice_coef: 0.4093 - val_loss: 0.9997 - val_dice_coef: 3.1530e-04
# Epoch 13/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5898 - dice_coef: 0.4102 - val_loss: 0.9961 - val_dice_coef: 0.0039
# Epoch 14/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5877 - dice_coef: 0.4123 - val_loss: 0.9930 - val_dice_coef: 0.0070
# Epoch 15/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5807 - dice_coef: 0.4193 - val_loss: 0.9992 - val_dice_coef: 8.0961e-04
# Epoch 16/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5768 - dice_coef: 0.4232 - val_loss: 0.9266 - val_dice_coef: 0.0734
# Epoch 17/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5781 - dice_coef: 0.4219 - val_loss: 0.7153 - val_dice_coef: 0.2847
# Epoch 18/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5733 - dice_coef: 0.4267 - val_loss: 0.6559 - val_dice_coef: 0.3441
# Epoch 19/100
# 21/21 [==============================] - 30s 1s/step - loss: 0.5725 - dice_coef: 0.4275 - val_loss: 0.5666 - val_dice_coef: 0.4334
# Epoch 20/100
# 21/21 [==============================] - 31s 1s/step - loss: 0.5680 - dice_coef: 0.4320 - val_loss: 0.5731 - val_dice_coef: 0.4269
# Epoch 21/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5648 - dice_coef: 0.4352 - val_loss: 0.5657 - val_dice_coef: 0.4343
# Epoch 22/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5650 - dice_coef: 0.4350 - val_loss: 0.6532 - val_dice_coef: 0.3468
# Epoch 23/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5629 - dice_coef: 0.4371 - val_loss: 0.8874 - val_dice_coef: 0.1126
# Epoch 24/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5626 - dice_coef: 0.4374 - val_loss: 0.6647 - val_dice_coef: 0.3353
# Epoch 25/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5602 - dice_coef: 0.4398 - val_loss: 0.5759 - val_dice_coef: 0.4241
# Epoch 26/100
# 21/21 [==============================] - 30s 1s/step - loss: 0.5586 - dice_coef: 0.4414 - val_loss: 0.5751 - val_dice_coef: 0.4249
# Epoch 27/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5581 - dice_coef: 0.4419 - val_loss: 0.5676 - val_dice_coef: 0.4324
# Epoch 28/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5653 - dice_coef: 0.4347 - val_loss: 0.6689 - val_dice_coef: 0.3311
# Epoch 29/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5632 - dice_coef: 0.4368 - val_loss: 0.5634 - val_dice_coef: 0.4366
# Epoch 30/100
# 21/21 [==============================] - 30s 1s/step - loss: 0.5619 - dice_coef: 0.4381 - val_loss: 0.5512 - val_dice_coef: 0.4488
# Epoch 31/100
# 21/21 [==============================] - 30s 1s/step - loss: 0.5579 - dice_coef: 0.4421 - val_loss: 0.5502 - val_dice_coef: 0.4498
# Epoch 32/100
# 21/21 [==============================] - 31s 1s/step - loss: 0.5602 - dice_coef: 0.4398 - val_loss: 0.5646 - val_dice_coef: 0.4354
# Epoch 33/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5563 - dice_coef: 0.4437 - val_loss: 0.5542 - val_dice_coef: 0.4458
# Epoch 34/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5558 - dice_coef: 0.4442 - val_loss: 0.5549 - val_dice_coef: 0.4451
# Epoch 35/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5570 - dice_coef: 0.4430 - val_loss: 0.5655 - val_dice_coef: 0.4345
# Epoch 36/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5557 - dice_coef: 0.4443 - val_loss: 0.6023 - val_dice_coef: 0.3977
# Epoch 37/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5552 - dice_coef: 0.4448 - val_loss: 0.5492 - val_dice_coef: 0.4508
# Epoch 38/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5548 - dice_coef: 0.4452 - val_loss: 0.5508 - val_dice_coef: 0.4492
# Epoch 39/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5554 - dice_coef: 0.4446 - val_loss: 0.5530 - val_dice_coef: 0.4470
# Epoch 40/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5558 - dice_coef: 0.4442 - val_loss: 0.5702 - val_dice_coef: 0.4298
# Epoch 41/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5553 - dice_coef: 0.4447 - val_loss: 0.5547 - val_dice_coef: 0.4453
# Epoch 42/100
# 21/21 [==============================] - 30s 1s/step - loss: 0.5540 - dice_coef: 0.4460 - val_loss: 0.5538 - val_dice_coef: 0.4462
# Epoch 43/100
# 21/21 [==============================] - 30s 1s/step - loss: 0.5532 - dice_coef: 0.4468 - val_loss: 0.5546 - val_dice_coef: 0.4454
# Epoch 44/100
# 21/21 [==============================] - 30s 1s/step - loss: 0.5526 - dice_coef: 0.4474 - val_loss: 0.5578 - val_dice_coef: 0.4422
# Epoch 45/100
# 21/21 [==============================] - 30s 1s/step - loss: 0.5518 - dice_coef: 0.4482 - val_loss: 0.5509 - val_dice_coef: 0.4491
# Epoch 46/100
# 21/21 [==============================] - 30s 1s/step - loss: 0.5523 - dice_coef: 0.4477 - val_loss: 0.5561 - val_dice_coef: 0.4439
# Epoch 47/100
# 21/21 [==============================] - 31s 1s/step - loss: 0.5529 - dice_coef: 0.4471 - val_loss: 0.5503 - val_dice_coef: 0.4497
# Epoch 48/100
# 21/21 [==============================] - 31s 1s/step - loss: 0.5513 - dice_coef: 0.4487 - val_loss: 0.5540 - val_dice_coef: 0.4460
# Epoch 49/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5511 - dice_coef: 0.4489 - val_loss: 0.5505 - val_dice_coef: 0.4495
# Epoch 50/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5505 - dice_coef: 0.4495 - val_loss: 0.5522 - val_dice_coef: 0.4478
# Epoch 51/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5523 - dice_coef: 0.4477 - val_loss: 0.5503 - val_dice_coef: 0.4497
# Epoch 52/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5545 - dice_coef: 0.4455 - val_loss: 0.5519 - val_dice_coef: 0.4481
# Epoch 53/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5551 - dice_coef: 0.4449 - val_loss: 0.5608 - val_dice_coef: 0.4392
# Epoch 54/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5543 - dice_coef: 0.4457 - val_loss: 0.5515 - val_dice_coef: 0.4485
# Epoch 55/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5524 - dice_coef: 0.4476 - val_loss: 0.5496 - val_dice_coef: 0.4504
# Epoch 56/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5523 - dice_coef: 0.4477 - val_loss: 0.5505 - val_dice_coef: 0.4495
# Epoch 57/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5511 - dice_coef: 0.4489 - val_loss: 0.5503 - val_dice_coef: 0.4497
# Epoch 58/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5504 - dice_coef: 0.4496 - val_loss: 0.5508 - val_dice_coef: 0.4492
# Epoch 59/100
# 21/21 [==============================] - 30s 1s/step - loss: 0.5499 - dice_coef: 0.4501 - val_loss: 0.5490 - val_dice_coef: 0.4510
# Epoch 60/100
# 21/21 [==============================] - 30s 1s/step - loss: 0.5504 - dice_coef: 0.4496 - val_loss: 0.5513 - val_dice_coef: 0.4487
# Epoch 61/100
# 21/21 [==============================] - 30s 1s/step - loss: 0.5496 - dice_coef: 0.4504 - val_loss: 0.5489 - val_dice_coef: 0.4511
# Epoch 62/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5500 - dice_coef: 0.4500 - val_loss: 0.5545 - val_dice_coef: 0.4455
# Epoch 63/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5499 - dice_coef: 0.4501 - val_loss: 0.5520 - val_dice_coef: 0.4480
# Epoch 64/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5496 - dice_coef: 0.4504 - val_loss: 0.5513 - val_dice_coef: 0.4487
# Epoch 65/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5496 - dice_coef: 0.4504 - val_loss: 0.5511 - val_dice_coef: 0.4489
# Epoch 66/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5498 - dice_coef: 0.4502 - val_loss: 0.5509 - val_dice_coef: 0.4491
# Epoch 67/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5503 - dice_coef: 0.4497 - val_loss: 0.5533 - val_dice_coef: 0.4467
# Epoch 68/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5502 - dice_coef: 0.4498 - val_loss: 0.5581 - val_dice_coef: 0.4419
# Epoch 69/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5492 - dice_coef: 0.4508 - val_loss: 0.5539 - val_dice_coef: 0.4461
# Epoch 70/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5496 - dice_coef: 0.4504 - val_loss: 0.5594 - val_dice_coef: 0.4406
# Epoch 71/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5510 - dice_coef: 0.4490 - val_loss: 0.5532 - val_dice_coef: 0.4468
# Epoch 72/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5501 - dice_coef: 0.4499 - val_loss: 0.5509 - val_dice_coef: 0.4491
# Epoch 73/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5495 - dice_coef: 0.4505 - val_loss: 0.5498 - val_dice_coef: 0.4502
# Epoch 74/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5490 - dice_coef: 0.4510 - val_loss: 0.5497 - val_dice_coef: 0.4503
# Epoch 75/100
# 21/21 [==============================] - 30s 1s/step - loss: 0.5489 - dice_coef: 0.4511 - val_loss: 0.5497 - val_dice_coef: 0.4503
# Epoch 76/100
# 21/21 [==============================] - 31s 1s/step - loss: 0.5516 - dice_coef: 0.4484 - val_loss: 0.5748 - val_dice_coef: 0.4252
# Epoch 77/100
# 21/21 [==============================] - 30s 1s/step - loss: 0.5509 - dice_coef: 0.4491 - val_loss: 0.5493 - val_dice_coef: 0.4507
# Epoch 78/100
# 21/21 [==============================] - 31s 1s/step - loss: 0.5498 - dice_coef: 0.4502 - val_loss: 0.5496 - val_dice_coef: 0.4504
# Epoch 79/100
# 21/21 [==============================] - 30s 1s/step - loss: 0.5494 - dice_coef: 0.4506 - val_loss: 0.5496 - val_dice_coef: 0.4504
# Epoch 80/100
# 21/21 [==============================] - 30s 1s/step - loss: 0.5484 - dice_coef: 0.4516 - val_loss: 0.5497 - val_dice_coef: 0.4503
# Epoch 81/100
# 21/21 [==============================] - 30s 1s/step - loss: 0.5486 - dice_coef: 0.4514 - val_loss: 0.5491 - val_dice_coef: 0.4509
# Epoch 82/100
# 21/21 [==============================] - 30s 1s/step - loss: 0.5495 - dice_coef: 0.4505 - val_loss: 0.5563 - val_dice_coef: 0.4437
# Epoch 83/100
# 21/21 [==============================] - 30s 1s/step - loss: 0.5493 - dice_coef: 0.4507 - val_loss: 0.5514 - val_dice_coef: 0.4486
# Epoch 84/100
# 21/21 [==============================] - 31s 1s/step - loss: 0.5484 - dice_coef: 0.4516 - val_loss: 0.5506 - val_dice_coef: 0.4494
# Epoch 85/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5478 - dice_coef: 0.4522 - val_loss: 0.5501 - val_dice_coef: 0.4499
# Epoch 86/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5493 - dice_coef: 0.4507 - val_loss: 0.5507 - val_dice_coef: 0.4493
# Epoch 87/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5486 - dice_coef: 0.4514 - val_loss: 0.5539 - val_dice_coef: 0.4461
# Epoch 88/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5487 - dice_coef: 0.4513 - val_loss: 0.5532 - val_dice_coef: 0.4468
# Epoch 89/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5491 - dice_coef: 0.4509 - val_loss: 0.5500 - val_dice_coef: 0.4500
# Epoch 90/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5483 - dice_coef: 0.4517 - val_loss: 0.5503 - val_dice_coef: 0.4497
# Epoch 91/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5485 - dice_coef: 0.4515 - val_loss: 0.5509 - val_dice_coef: 0.4491
# Epoch 92/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5481 - dice_coef: 0.4519 - val_loss: 0.5521 - val_dice_coef: 0.4479
# Epoch 93/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5486 - dice_coef: 0.4514 - val_loss: 0.5500 - val_dice_coef: 0.4500
# Epoch 94/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5478 - dice_coef: 0.4522 - val_loss: 0.5476 - val_dice_coef: 0.4524
# Epoch 95/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5478 - dice_coef: 0.4522 - val_loss: 0.5498 - val_dice_coef: 0.4502
# Epoch 96/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5474 - dice_coef: 0.4526 - val_loss: 0.5490 - val_dice_coef: 0.4510
# Epoch 97/100
# 21/21 [==============================] - 30s 1s/step - loss: 0.5477 - dice_coef: 0.4523 - val_loss: 0.5515 - val_dice_coef: 0.4485
# Epoch 98/100
# 21/21 [==============================] - 31s 1s/step - loss: 0.5486 - dice_coef: 0.4514 - val_loss: 0.5502 - val_dice_coef: 0.4498
# Epoch 99/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5486 - dice_coef: 0.4514 - val_loss: 0.5629 - val_dice_coef: 0.4371
# Epoch 100/100
# 21/21 [==============================] - 29s 1s/step - loss: 0.5489 - dice_coef: 0.4511 - val_loss: 0.5514 - val_dice_coef: 0.4486
# 3/3 [==============================] - 9s 4s/step - loss: 0.5899 - dice_coef: 0.4139
# Test Loss: 0.5899434685707092
# Test Accuracy: 0.41391611099243164

# %%
model.save_weights("/content/drive/MyDrive/MulTiFINAL.h5")

# %%
HISTORY =  history

# %%
# Extracting training and validation loss from the history object
train_loss = HISTORY.history['loss']
val_loss = HISTORY.history['val_loss']

epochs = range(1, len(train_loss) + 1)

# Plotting the training and validation loss
plt.plot(epochs, train_loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
X.shape
# Out:
# (8, 256, 256, 3)

# %%
Y.shape
# Out:
# (8, 256, 256, 1)

# %%
print("\n      Ground Truth            Predicted Value")

for i in range(test_steps):
    # Dataset for prediction
    x, y = test_gen.__getitem__(i)

    # Predict segmentation masks using the trained model
    result = model.predict(x)
    result = result > 0.2

    for i in range(len(result)):
        fig = plt.figure()
        fig.subplots_adjust(hspace=0.4, wspace=0.4)

        ax = fig.add_subplot(1, 2, 1)
        ax.imshow(np.reshape(y[i]*255, (image_size, image_size)), cmap="gray")
        ax.set_title("Ground Truth")

        ax = fig.add_subplot(1, 2, 2)
        ax.imshow(np.reshape(result[i]*255, (image_size, image_size)), cmap="gray")
        ax.set_title("Predicted Value")
# Out:
#       Ground Truth            Predicted Value
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step

# %%
print("\n      Ground Truth            Predicted Value")

for i in range(len(X)):
    # Dataset for prediction
    x = X[i]
    y = Y[i]

    # Reshape the input image for prediction
    x = np.expand_dims(x, axis=0)

    # Predict segmentation mask using the trained model
    result = model.predict(x)
    result = result > 0.2

    # Plot the ground truth and predicted masks
    fig = plt.figure()
    fig.subplots_adjust(hspace=0.4, wspace=0.4)

    ax = fig.add_subplot(1, 2, 1)
    ax.imshow(np.reshape(y*255, (image_size, image_size)), cmap="gray")
    ax.set_title("Ground Truth")

    ax = fig.add_subplot(1, 2, 2)
    ax.imshow(np.reshape(result*255, (image_size, image_size)), cmap="gray")
    ax.set_title("Predicted Mask")
# Out:
#       Ground Truth            Predicted Value
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step

# %%
test_gen = TestGen(test_ids, train_path, image_size=image_size, batch_size=8)

# %%
# !pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (0.24.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (1.26.4)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (1.13.1)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (3.3)
# Requirement already satisfied: pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (10.4.0)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (2.35.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (2024.9.20)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (0.4)

# %%
import numpy as np
from skimage.metrics import structural_similarity as compare_ssim

def calculate_ssim(y_true, y_pred):
    y_true = y_true.astype(np.float64)
    y_pred = y_pred.astype(np.float64)

    # Get the shape of the images
    height, width = y_true.shape[:2]

    # Check if the images are large enough
    if height < 7 or width < 7:
        print("Images are too small for SSIM calculation. Size:", (height, width))
        return None  # or return a suitable default value, e.g., 0 or np.nan

    # Calculate SSIM with a specified win_size (e.g., 11)
    ssim = compare_ssim(y_true, y_pred, data_range=y_pred.max() - y_pred.min(),
                        win_size=11, multichannel=True)

    return ssim

# Calculate SSIM
ssim_score = calculate_ssim(Y[0], result[0])  # Assuming Y and result are arrays of images
if ssim_score is not None:
    print("SSIM Score:", ssim_score)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-cb8e0b2dfd36> in <cell line: 23>()
#      21
#      22 # Calculate SSIM
# ---> 23 ssim_score = calculate_ssim(Y[0], result[0])  # Assuming Y and result are arrays of images
#      24 if ssim_score is not None:
#      25     print("SSIM Score:", ssim_score)
#
# <ipython-input-44-cb8e0b2dfd36> in calculate_ssim(y_true, y_pred)
#      15
#      16     # Calculate SSIM with a specified win_size (e.g., 11)
# ---> 17     ssim = compare_ssim(y_true, y_pred, data_range=y_pred.max() - y_pred.min(),
#      18                         win_size=11, multichannel=True)
#      19
#
# /usr/local/lib/python3.10/dist-packages/skimage/metrics/_structural_similarity.py in structural_similarity(im1, im2, win_size, gradient, data_range, channel_axis, gaussian_weights, full, **kwargs)
#     184
#     185     if np.any((np.asarray(im1.shape) - win_size) < 0):
# --> 186         raise ValueError(
#     187             'win_size exceeds image extent. '
#     188             'Either ensure that your images are '
#
# ValueError: win_size exceeds image extent. Either ensure that your images are at least 7x7; or pass win_size explicitly in the function call, with an odd value less than or equal to the smaller side of your images. If your images are multichannel (with color channels), set channel_axis to the axis number corresponding to the channels.

# %%
print("True Image Shape:", Y[0].shape)
print("Predicted Image Shape:", result[0].shape)
# Out:
# True Image Shape: (256, 256, 1)
# Predicted Image Shape: (256, 256, 1)

# %%
# Initialize variables to store total dice coefficient and number of batches
total_dice_coef = 0.0
num_batches = 0

# Iterate over each batch in the test generator
for batch_index in range(test_steps):
    # Get the batch of test data
    x_test, y_test = test_gen.__getitem__(batch_index)

    # Predict segmentation masks using the trained model
    pred_masks = model.predict(x_test)

    # Calculate the Dice coefficient for the current batch
    batch_dice_coef = dice_coef(tf.cast(y_test, tf.float32), tf.cast(pred_masks, tf.float32)).numpy()

    # Accumulate the total Dice coefficient and increment the batch count
    total_dice_coef += batch_dice_coef
    num_batches += 1

# Calculate the average Dice coefficient across all batches
average_dice_coef = total_dice_coef / num_batches

# Print the average Dice coefficient (which serves as the accuracy)
print("Average Dice Coefficient :", average_dice_coef)
# Out:
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 25ms/step
# Average Dice Coefficient : 0.396145224571228

# %%
def calculate_iou(y_true, y_pred):
    intersection = np.sum(np.logical_and(y_true, y_pred))
    union = np.sum(np.logical_or(y_true, y_pred))
    iou = intersection / (union + 1e-6)  # Add a small epsilon to avoid division by zero
    return iou

# Initialize variables to store total IoU and count of images
total_iou = 0
image_count = 0

# Iterate over test images
for i in range(test_steps):
    # Dataset for prediction
    x, y_true = test_gen.__getitem__(i)

    # Predict segmentation masks using the trained model
    y_pred = model.predict(x) > 0.2

    # Calculate IoU for each image
    for j in range(len(y_true)):
        single_iou = calculate_iou(y_true[j], y_pred[j])
        print(f"IoU for image {image_count + 1}: {single_iou}")
        total_iou += single_iou
        image_count += 1

# Calculate mean IoU
mean_iou = total_iou / image_count
print(f"Mean IoU for {image_count} images: {mean_iou}")
# Out:
# 1/1 [==============================] - 0s 36ms/step
# IoU for image 1: 0.32679738540732195
# IoU for image 2: 0.3734542453640113
# IoU for image 3: 0.5060679605508884
# IoU for image 4: 0.2692640690309402
# IoU for image 5: 0.39812206535387595
# 1/1 [==============================] - 0s 40ms/step
# IoU for image 6: 0.19589257488476097
# IoU for image 7: 0.42685589473050667
# IoU for image 8: 0.8216527192355373
# IoU for image 9: 0.8119658114319751
# IoU for image 10: 0.8025415436925303
# 1/1 [==============================] - 0s 43ms/step
# IoU for image 11: 0.8061153573272304
# IoU for image 12: 0.8203184224258389
# IoU for image 13: 0.819987187174896
# IoU for image 14: 0.8210526308587257
# IoU for image 15: 0.900491399938273
# Mean IoU for 15 images: 0.6067052844938208

# %%
import numpy as np

def calculate_miss_rate(y_true, y_pred):
    # Flatten the ground truth and predicted masks
    y_true_f = y_true.flatten()

    # Threshold y_pred to obtain binary masks
    y_pred_binary = (y_pred > 0.5).astype(np.int32)
    y_pred_f = y_pred_binary.flatten()

    # True negatives (TN): Ground truth negative and prediction negative
    true_negatives = np.sum((1 - y_true_f) * (1 - y_pred_f))

    # False negatives (FN): Ground truth positive and prediction negative
    false_negatives = np.sum(y_true_f * (1 - y_pred_f))

    # Miss rate = FN / (FN + TN)
    miss_rate = false_negatives / (false_negatives + true_negatives + np.finfo(float).eps)

    return miss_rate

def calculate_specificity(y_true, y_pred):
    # Convert predictions to binary values
    y_pred_binary = (y_pred > 0.5).astype(np.int32)

    # True negatives: actual negatives correctly identified
    tn = np.sum((y_true == 0) & (y_pred_binary == 0))

    # False positives: actual negatives incorrectly identified as positives
    fp = np.sum((y_true == 0) & (y_pred_binary == 1))

    # Specificity = TN / (TN + FP)
    specificity = tn / (tn + fp + np.finfo(float).eps)

    return specificity

def calculate_npv(y_true, y_pred):
    # Convert predicted values to binary (0 or 1)
    y_pred_binary = (y_pred > 0.5).astype(int)

    # Calculate true negatives (TN), false negatives (FN)
    # true positives (TP), false positives (FP)
    TN = np.sum((1 - y_true) * (1 - y_pred_binary))
    FN = np.sum(y_true * (1 - y_pred_binary))
    TP = np.sum(y_true * y_pred_binary)
    FP = np.sum((1 - y_true) * y_pred_binary)

    # Calculate Negative Predictive Value (NPV)
    NPV = TN / (TN + FN + np.finfo(float).eps)

    return NPV

def calculate_fall_out(y_true, y_pred):
    # Flatten the ground truth and predicted masks
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()

    # Convert the predicted probabilities to binary predictions
    y_pred_binary = (y_pred_f > 0.5).astype(int)

    # Calculate confusion matrix
    tp = np.sum((y_true_f == 1) & (y_pred_binary == 1))
    tn = np.sum((y_true_f == 0) & (y_pred_binary == 0))
    fp = np.sum((y_true_f == 0) & (y_pred_binary == 1))
    fn = np.sum((y_true_f == 1) & (y_pred_binary == 0))

    # Calculate fall-out
    fall_out = fp / (fp + tn + np.finfo(float).eps)  # Add a small value to avoid division by zero

    return fall_out

def pixel_accuracy(y_true, y_pred):
    # Convert predictions to binary masks
    y_pred = (y_pred > 0.5).astype(int)

    # Calculate pixel-wise accuracy
    correct_pixels = np.sum((y_true == y_pred).astype(int))
    total_pixels = np.prod(y_true.shape)
    accuracy = correct_pixels / total_pixels

    return accuracy

def calculate_accuracy(y_true, y_pred, threshold=0.5):
    # Convert predicted probabilities to binary masks using a threshold
    y_pred_binary = (y_pred > threshold).astype(int)

    # Flatten the arrays to facilitate pixel-wise comparison
    y_true_flat = y_true.flatten()
    y_pred_flat = y_pred_binary.flatten()

    # Calculate the proportion of correctly predicted pixels
    accuracy = np.mean(y_true_flat == y_pred_flat)

    return accuracy

# Assuming you have computed the model predictions (result) and ground truth (y)
miss_rate = calculate_miss_rate(y, result)
specificity = calculate_specificity(y, result)
npv_score = calculate_npv(y, result)
fall_out = calculate_fall_out(y, result)
accuracy = pixel_accuracy(y, result)
print("Miss Rate:", miss_rate)
print("Specificity:", specificity)
print("Negative Predictive Value (NPV):", npv_score)
print("Fall-Out:", fall_out)
print("Pixel-wise Accuracy:", accuracy)
print("Model Accuracy:", calculate_accuracy(y, result))
# Out:
# Miss Rate: 0.0011038512176542625
# Specificity: 1.0
# Negative Predictive Value (NPV): 0.9988961487823458
# Fall-Out: 0.0
# Pixel-wise Accuracy: 0.9708251953125
# Model Accuracy: 0.9708251953125

# %%
def jaccard_coef(y_true, y_pred):
    y_true = K.cast(y_true, 'float32')
    y_pred = K.cast(y_pred, 'float32')

    intersection = K.sum(y_true * y_pred, axis=-1)
    union = K.sum(y_true, axis=-1) + K.sum(y_pred, axis=-1) - intersection

    return (intersection + smooth) / (union + smooth)

# %%
jaccard_scores = []

for i in range(test_steps):
    # Dataset for prediction
    x, y_true = test_gen.__getitem__(i)

    # Predict segmentation masks using the trained model
    y_pred = model.predict(x)
    y_pred = y_pred > 0.2

    for i in range(len(y_pred)):
        jaccard_score = jaccard_coef(y_true[i], y_pred[i])
        jaccard_scores.append(jaccard_score)

# Calculate the average Jaccard coefficient
average_jaccard = np.mean(jaccard_scores)
print("Average Jaccard Coefficient:", average_jaccard)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# Average Jaccard Coefficient: 0.9941394

# %%
import numpy as np

def calculate_sensitivity(y_true, y_pred):
    # Flatten the arrays to make sure they are 1D
    y_true_flat = y_true.flatten()
    y_pred_flat = y_pred.flatten()

    # Calculate True Positives and False Negatives
    TP = np.sum((y_true_flat == 1) & (y_pred_flat == 1))  # True Positives
    FN = np.sum((y_true_flat == 1) & (y_pred_flat == 0))  # False Negatives

    # Avoid division by zero
    if (TP + FN) == 0:
        return 0.0  # No positive cases

    # Calculate Sensitivity
    sensitivity = TP / (TP + FN)

    return sensitivity

# Example usage
# Assuming Y is the ground truth and result is the predicted output
sensitivity_score = calculate_sensitivity(Y[0], result[0])  # Use the appropriate index for your data
print("Sensitivity Score:", sensitivity_score)
# Out:
# Sensitivity Score: 0.0
